# %% [markdown]
# <font color="blue" size="6">Groupby-1</font>

# %% [markdown]
# Pandas groupby is used for grouping the data according to the categories and applying a function to the categories.

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('DATASETS\\titanic.csv')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# GroupbyPlass with average survival rate
df.groupby('Pclass').agg({'Survived':np.mean})
# Out:
#         Survived
# Pclass
# 1       0.629630
# 2       0.472826
# 3       0.242363

# %%
# GroupbyPlassand sex with average survival rate and number of persons survived in each section
df.groupby(['Sex','Pclass']).agg({'Survived':[np.mean,np.sum]})
# Out:
#                Survived
#                    mean sum
# Sex    Pclass
# female 1       0.968085  91
#        2       0.921053  70
#        3       0.500000  72
# male   1       0.368852  45
#        2       0.157407  17
#        3       0.135447  47

# %%
#Sorts according to the Sex
df.groupby(['Sex','Pclass']).agg({'Survived':[np.mean,np.sum]}).reset_index()
# Out:
#       Sex Pclass  Survived
#                       mean sum
# 0  female      1  0.968085  91
# 1  female      2  0.921053  70
# 2  female      3  0.500000  72
# 3    male      1  0.368852  45
# 4    male      2  0.157407  17
# 5    male      3  0.135447  47

# %%
#(max fare-min fare) for each sex and for each pclass
df.groupby(['Sex','Pclass']).agg({'Fare':lambda x:np.max(x)-np.min(x)})
# Out:
#                    Fare
# Sex    Pclass
# female 1       486.4000
#        2        54.5000
#        3        62.8000
# male   1       512.3292
#        2        73.5000
#        3        69.5500

# %%
# for each pclass and for each sex max fare min fare and difference
def mimax(x):
    return np.max(x)-np.min(x)

df.groupby(['Sex','Pclass']).agg({'Fare':[np.min,np.max,mimax]})
# Out:
#                   Fare
#                   amin      amax     mimax
# Sex    Pclass
# female 1       25.9292  512.3292  486.4000
#        2       10.5000   65.0000   54.5000
#        3        6.7500   69.5500   62.8000
# male   1        0.0000  512.3292  512.3292
#        2        0.0000   73.5000   73.5000
#        3        0.0000   69.5500   69.5500
