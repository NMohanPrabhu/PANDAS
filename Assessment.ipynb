# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("CSE_RESULT.csv")

# %%
df
# Out:
#     RollNo             Name Dept Sec  Gender        Type Category Sub_1  \
# 0     1000        Abinaya.L  CSE   A  Female      Hostel   Topper     O
# 1     1001         Abitha.R  CSE   A  Female  Dayscholar  Average     B
# 2     1002           Ajay.M  CSE   A    Male      Hostel   Topper     O
# 3     1003         Ajitha.K  CSE   A  Female  Dayscholar  Average     B
# 4     1004           Bala.C  CSE   A    Male      Hostel  Average     B
# 5     1005       Caterine.J  CSE   A  Female  Dayscholar  Average     B
# 6     1006          Danny.I  CSE   A    Male      Hostel     Weak     U
# 7     1007           Deva.D  CSE   A    Male  Dayscholar  Average     B
# 8     1008           Devi.P  CSE   A  Female      Hostel     Weak     C
# 9     1009         Dhivya.R  CSE   A  Female  Dayscholar  Average     B
# 10    1010        Francis.K  CSE   A    Male      Hostel     Weak     D
# 11    1011         Harish.P  CSE   A    Male  Dayscholar   Topper     O
# ...

# %% [markdown]
# <ol> <font color="Blue" size="4">
#   <li>Find total number of all clear and failed students</li>
#   <li>Find percentage of all clear and failed students</li>
#    <li>Determine the CGPA of all the students</li>
#    <li>List out top 5 students CGPA</li>
#    <li>Determine which type of students (Hostle vs Dayscholar) from a particular class (SEC A vs SEC B) have performed well ie. Pass</li>
#      <li>Determine which Gender (Male /Female) of students  from a particular class (SEC A vs SEC B) have performed well ie. Pass </li>
#     <li>Determine which subject (Sub_1) staff from class A and class B have produced better result.Justify your answer </li>
# </font> </ol>

# %% [markdown]
# <font color="green" size="4">Note:</font>
# <ol> <font color="red" size="4">
#   <li>Sub_1,Sub_2,Sub_3,Sub_4,Sub_5,Sub_6 talks about subject name</li>
#   <li>Lab_1,Lab_2 talks about Lab subject name</li>
#     <li>S1_GP to S6_GP and L1_GP to L2_GP talks about grade point obtained by the students in their respective subjects</li>
#     <li>S1_C to S6_C and L1_C to L2_C talks about credit point obtained by the students in their respective subjects</li>
#   <li>Column Tot_Credit tells the total credits allocated to a particular semester =24 for all students</li>
#
#    <li>For any subject the grade name and points are as follows O=10,A=9,B=8,C=7,D=6,E=5,U=0 ie fail</li>
#
# </font> </ol>

# %% [markdown]
# <font color="pink" size="4">CGPA Formula = (Σ (GradePoint × Credit)) ÷ Tot_Credit</font>

# %% [markdown]
# <font color="yellow" size="6"> All The best - Feel free to ask any doubts to volunteers </font>
